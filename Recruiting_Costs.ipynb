# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/Ron/Documents/recruiting_costs.csv')

# %%
df
# Out:
#                          Employment Source  January   February  March  April  \
# 0                                Billboard       520       520    520    520
# 1                            Careerbuilder       410       410    410    820
# 2               Company Intranet - Partner         0         0      0      0
# 3                       Diversity Job Fair         0      5129      0      0
# 4                        Employee Referral         0         0      0      0
# 5                                Glassdoor         0         0      0      0
# 6                      Information Session         0         0      0      0
# 7                          Internet Search         0         0      0      0
# 8                                 MBTA ads       640       640    640    640
# 9                              Monster.com       500       500    500    440
# 10                      Newspager/Magazine       629       510    293    810
# ...

# %%
df.dtypes
# Out:
# Employment Source    object
# January               int64
# February              int64
# March                 int64
# April                 int64
# May                   int64
# June                  int64
# July                  int64
# August                int64
# September             int64
# October               int64
# November              int64
# December              int64
# Total                 int64
# dtype: object

# %%
df=df.rename(columns={'Employment Source': 'RecruitmentSource'})

# %%
df
# Out:
#                          RecruitmentSource  January   February  March  April  \
# 0                                Billboard       520       520    520    520
# 1                            Careerbuilder       410       410    410    820
# 2               Company Intranet - Partner         0         0      0      0
# 3                       Diversity Job Fair         0      5129      0      0
# 4                        Employee Referral         0         0      0      0
# 5                                Glassdoor         0         0      0      0
# 6                      Information Session         0         0      0      0
# 7                          Internet Search         0         0      0      0
# 8                                 MBTA ads       640       640    640    640
# 9                              Monster.com       500       500    500    440
# 10                      Newspager/Magazine       629       510    293    810
# ...

# %%
df.to_csv(r'C:\Users\Ron\Documents\recruiting_costs2.csv')
