# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('C:/Users/Ron/Documents/salary_grid.csv', header = 1, index_col=False)

# %%
df
# Out:
#                         Position      Min       Mid       Max  Min.1  Mid.1  \
# 0       Administrative Assistant  30000.0   40000.0   50000.0  14.42  19.23
# 1   Sr. Administrative Assistant  35000.0   45000.0   55000.0  16.83  21.63
# 2                   Accountant I  42274.0   51425.0   62299.0  20.32  24.72
# 3                  Accountant II  50490.0   62158.0   74658.0  24.27  29.88
# 4                 Sr. Accountant  63264.0   76988.0   92454.0  30.42  37.01
# 5               Network Engineer  50845.0   66850.0   88279.0  24.44  32.14
# 6           Sr. Network Engineer  79428.0   99458.0  120451.0  38.19  47.82
# 7         Database Administrator  50569.0   68306.0   93312.0  24.31  32.84
# 8                        Sr. DBA  92863.0  116007.0  139170.0  44.65  55.77
# 9        Production Technician I  30000.0   40000.0   50000.0  14.42  19.23
# 10      Production Technician II  38000.0   48000.0   58000.0  18.27  23.08
# ...

# %%
df.dtypes
# Out:
# Position        object
# Min            float64
# Mid            float64
# Max            float64
# Min.1          float64
# Mid.1          float64
# Max.1          float64
# Unnamed: 7     float64
# Unnamed: 8     float64
# Unnamed: 9     float64
# Unnamed: 10    float64
# Unnamed: 11    float64
# Unnamed: 12    float64
# Unnamed: 13    float64
# Unnamed: 14    float64
# dtype: object

# %%
df=df.rename(columns={'Min': 'SalaryMin', 'Mid': 'SalaryMid', 'Max': 'SalaryMax', 'Min.1': 'PayRateMin',
                     'Mid.1': 'PayRateMid', 'Max.1': 'PayRateMax'})

# %%
df2=df.iloc[0:12]

# %%
df2
# Out:
#                         Position  SalaryMin  SalaryMid  SalaryMax  PayRateMin  \
# 0       Administrative Assistant    30000.0    40000.0    50000.0       14.42
# 1   Sr. Administrative Assistant    35000.0    45000.0    55000.0       16.83
# 2                   Accountant I    42274.0    51425.0    62299.0       20.32
# 3                  Accountant II    50490.0    62158.0    74658.0       24.27
# 4                 Sr. Accountant    63264.0    76988.0    92454.0       30.42
# 5               Network Engineer    50845.0    66850.0    88279.0       24.44
# 6           Sr. Network Engineer    79428.0    99458.0   120451.0       38.19
# 7         Database Administrator    50569.0    68306.0    93312.0       24.31
# 8                        Sr. DBA    92863.0   116007.0   139170.0       44.65
# 9        Production Technician I    30000.0    40000.0    50000.0       14.42
# 10      Production Technician II    38000.0    48000.0    58000.0       18.27
# ...

# %%
df3=df2.iloc[:,0:7]

# %%
df3
# Out:
#                         Position  SalaryMin  SalaryMid  SalaryMax  PayRateMin  \
# 0       Administrative Assistant    30000.0    40000.0    50000.0       14.42
# 1   Sr. Administrative Assistant    35000.0    45000.0    55000.0       16.83
# 2                   Accountant I    42274.0    51425.0    62299.0       20.32
# 3                  Accountant II    50490.0    62158.0    74658.0       24.27
# 4                 Sr. Accountant    63264.0    76988.0    92454.0       30.42
# 5               Network Engineer    50845.0    66850.0    88279.0       24.44
# 6           Sr. Network Engineer    79428.0    99458.0   120451.0       38.19
# 7         Database Administrator    50569.0    68306.0    93312.0       24.31
# 8                        Sr. DBA    92863.0   116007.0   139170.0       44.65
# 9        Production Technician I    30000.0    40000.0    50000.0       14.42
# 10      Production Technician II    38000.0    48000.0    58000.0       18.27
# ...

# %%
df3.dtypes
# Out:
# Position       object
# SalaryMin     float64
# SalaryMid     float64
# SalaryMax     float64
# PayRateMin    float64
# PayRateMid    float64
# PayRateMax    float64
# dtype: object

# %%
df3.to_csv(r'C:\Users\Ron\Documents\salary_grid2.csv')
