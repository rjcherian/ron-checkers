# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/Ron/Documents/HRDataset_v13.csv')

# %%
df.head()
# Out:
#           Employee_Name         EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0            Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1  LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2      Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3       Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4           Singh, Nan   1.307060e+09        0.0              0.0       0.0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  PayRate  ...  \
# 0          1.0     1.0          3.0                     1.0    28.50  ...
# 1          1.0     1.0          3.0                     0.0    23.00  ...
# 2          1.0     1.0          3.0                     0.0    29.00  ...
# 3          1.0     1.0          3.0                     0.0    21.50  ...
# 4          1.0     1.0          3.0                     0.0    16.56  ...
#
# ...

# %%
df.dtypes
# Out:
# Employee_Name                  object
# EmpID                         float64
# MarriedID                     float64
# MaritalStatusID               float64
# GenderID                      float64
# EmpStatusID                   float64
# DeptID                        float64
# PerfScoreID                   float64
# FromDiversityJobFairID        float64
# PayRate                       float64
# Termd                         float64
# PositionID                    float64
# Position                       object
# State                          object
# Zip                           float64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
df=df.rename(columns={'Employee_Name': 'EmployeeName', 'EmpID': 'EmployeeID',
                     'TermReason': 'ReasonForTerm', 'Zip': 'ZipCode', 'LastPerformanceReview_Date': 'LastPerformanceReviewDate'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 35 columns):
# EmployeeName                 310 non-null object
# EmployeeID                   310 non-null float64
# MarriedID                    310 non-null float64
# MaritalStatusID              310 non-null float64
# GenderID                     310 non-null float64
# EmpStatusID                  310 non-null float64
# DeptID                       310 non-null float64
# PerfScoreID                  310 non-null float64
# FromDiversityJobFairID       310 non-null float64
# PayRate                      310 non-null float64
# Termd                        310 non-null float64
# PositionID                   310 non-null float64
# Position                     310 non-null object
# State                        310 non-null object
# ZipCode                      310 non-null float64
# DOB                          310 non-null object
# Sex                          310 non-null object
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of              EmployeeName    EmployeeID  MarriedID  MaritalStatusID  GenderID  \
# 0              Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1    LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2        Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3         Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4             Singh, Nan   1.307060e+09        0.0              0.0       0.0
# ..                    ...           ...        ...              ...       ...
# 396                   NaN           NaN        NaN              NaN       NaN
# 397                   NaN           NaN        NaN              NaN       NaN
# 398                   NaN           NaN        NaN              NaN       NaN
# 399                   NaN           NaN        NaN              NaN       NaN
# 400                   NaN           NaN        NaN              NaN       NaN
#
# ...

# %%
df
# Out:
#              EmployeeName    EmployeeID  MarriedID  MaritalStatusID  GenderID  \
# 0              Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1    LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2        Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3         Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4             Singh, Nan   1.307060e+09        0.0              0.0       0.0
# ..                    ...           ...        ...              ...       ...
# 396                   NaN           NaN        NaN              NaN       NaN
# 397                   NaN           NaN        NaN              NaN       NaN
# 398                   NaN           NaN        NaN              NaN       NaN
# 399                   NaN           NaN        NaN              NaN       NaN
# 400                   NaN           NaN        NaN              NaN       NaN
#
# ...

# %%
df2=df.iloc[0:310]

# %%
df2
# Out:
#                EmployeeName    EmployeeID  MarriedID  MaritalStatusID  \
# 0                Brown, Mia  1.103024e+09        1.0              1.0
# 1      LaRotonda, William    1.106027e+09        0.0              2.0
# 2          Steans, Tyrone    1.302053e+09        0.0              0.0
# 3           Howard, Estelle  1.211051e+09        1.0              1.0
# 4               Singh, Nan   1.307060e+09        0.0              0.0
# ..                      ...           ...        ...              ...
# 305          Daniele, Ann    1.411071e+09        1.0              1.0
# 306          Lajiri,  Jyoti  1.108028e+09        1.0              1.0
# 307  Semizoglou, Jeremiah    9.040136e+08        1.0              1.0
# 308              South, Joe  1.308061e+09        0.0              0.0
# 309         Warfield, Sarah  1.301052e+09        0.0              4.0
#
#      GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  \
# ...

# %%
df2['DateofHire'] = pd.to_datetime(df2['DateofHire'])
# Out:
# C:\Users\Ron\Anaconda3\envs\dsi04\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['LastPerformanceReviewDate'] = pd.to_datetime(df2['LastPerformanceReviewDate'])
# Out:
# C:\Users\Ron\Anaconda3\envs\dsi04\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['DOB'] = pd.to_datetime(df2['DOB'])
# Out:
# C:\Users\Ron\Anaconda3\envs\dsi04\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['DateofTermination'] = pd.to_datetime(df2['DateofTermination'])
# Out:
# C:\Users\Ron\Anaconda3\envs\dsi04\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.dtypes
# Out:
# EmployeeName                         object
# EmployeeID                          float64
# MarriedID                           float64
# MaritalStatusID                     float64
# GenderID                            float64
# EmpStatusID                         float64
# DeptID                              float64
# PerfScoreID                         float64
# FromDiversityJobFairID              float64
# PayRate                             float64
# Termd                               float64
# PositionID                          float64
# Position                             object
# State                                object
# ZipCode                             float64
# DOB                          datetime64[ns]
# Sex                                  object
# MaritalDesc                          object
# CitizenDesc                          object
# HispanicLatino                       object
# RaceDesc                             object
# ...

# %%
df2.DOB
# Out:
# 0     1987-11-24
# 1     1984-04-26
# 2     1986-09-01
# 3     1985-09-16
# 4     1988-05-19
#          ...
# 305   2052-01-18
# 306   1986-04-23
# 307   1983-02-09
# 308   2065-09-09
# 309   1978-05-02
# Name: DOB, Length: 310, dtype: datetime64[ns]

# %%
df2.DateofHire
# Out:
# 0     2008-10-27
# 1     2014-01-06
# 2     2014-09-29
# 3     2015-02-16
# 4     2015-05-01
#          ...
# 305   2014-11-10
# 306   2014-11-10
# 307   2016-06-30
# 308   2014-11-10
# 309   2015-03-30
# Name: DateofHire, Length: 310, dtype: datetime64[ns]

# %%
df2.LastPerformanceReviewDate
# Out:
# 0     2019-01-15
# 1     2019-01-17
# 2     2019-01-18
# 3            NaT
# 4     2019-01-15
#          ...
# 305   2019-02-12
# 306   2019-01-07
# 307   2019-01-14
# 308   2019-01-02
# 309   2019-02-05
# Name: LastPerformanceReviewDate, Length: 310, dtype: datetime64[ns]

# %%
df2.DateofTermination
# Out:
# 0            NaT
# 1            NaT
# 2            NaT
# 3     2015-04-15
# 4            NaT
#          ...
# 305          NaT
# 306          NaT
# 307          NaT
# 308          NaT
# 309          NaT
# Name: DateofTermination, Length: 310, dtype: datetime64[ns]

# %%
df2.drop('DaysLateLast30', axis=1)
# Out:
#                EmployeeName    EmployeeID  MarriedID  MaritalStatusID  \
# 0                Brown, Mia  1.103024e+09        1.0              1.0
# 1      LaRotonda, William    1.106027e+09        0.0              2.0
# 2          Steans, Tyrone    1.302053e+09        0.0              0.0
# 3           Howard, Estelle  1.211051e+09        1.0              1.0
# 4               Singh, Nan   1.307060e+09        0.0              0.0
# ..                      ...           ...        ...              ...
# 305          Daniele, Ann    1.411071e+09        1.0              1.0
# 306          Lajiri,  Jyoti  1.108028e+09        1.0              1.0
# 307  Semizoglou, Jeremiah    9.040136e+08        1.0              1.0
# 308              South, Joe  1.308061e+09        0.0              0.0
# 309         Warfield, Sarah  1.301052e+09        0.0              4.0
#
#      GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  \
# ...

# %%
df2['Salary'] = df2.PayRate*40*52
# Out:
# C:\Users\Ron\Anaconda3\envs\dsi04\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#            EmployeeName    EmployeeID  MarriedID  MaritalStatusID  GenderID  \
# 0            Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1  LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2      Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3       Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4           Singh, Nan   1.307060e+09        0.0              0.0       0.0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  PayRate  ...  \
# 0          1.0     1.0          3.0                     1.0    28.50  ...
# 1          1.0     1.0          3.0                     0.0    23.00  ...
# 2          1.0     1.0          3.0                     0.0    29.00  ...
# 3          1.0     1.0          3.0                     0.0    21.50  ...
# 4          1.0     1.0          3.0                     0.0    16.56  ...
#
# ...

# %%
df2.drop('DaysLateLast30', axis=1, inplace=True)
# Out:
# C:\Users\Ron\Anaconda3\envs\dsi04\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df2.head()
# Out:
#            EmployeeName    EmployeeID  MarriedID  MaritalStatusID  GenderID  \
# 0            Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1  LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2      Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3       Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4           Singh, Nan   1.307060e+09        0.0              0.0       0.0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  PayRate  ...  \
# 0          1.0     1.0          3.0                     1.0    28.50  ...
# 1          1.0     1.0          3.0                     0.0    23.00  ...
# 2          1.0     1.0          3.0                     0.0    29.00  ...
# 3          1.0     1.0          3.0                     0.0    21.50  ...
# 4          1.0     1.0          3.0                     0.0    16.56  ...
#
# ...

# %%
df2.dtypes
# Out:
# EmployeeName                         object
# EmployeeID                          float64
# MarriedID                           float64
# MaritalStatusID                     float64
# GenderID                            float64
# EmpStatusID                         float64
# DeptID                              float64
# PerfScoreID                         float64
# FromDiversityJobFairID              float64
# PayRate                             float64
# Termd                               float64
# PositionID                          float64
# Position                             object
# State                                object
# ZipCode                             float64
# DOB                          datetime64[ns]
# Sex                                  object
# MaritalDesc                          object
# CitizenDesc                          object
# HispanicLatino                       object
# RaceDesc                             object
# ...

# %%
df2.head(273)
# Out:
#                EmployeeName    EmployeeID  MarriedID  MaritalStatusID  \
# 0                Brown, Mia  1.103024e+09        1.0              1.0
# 1      LaRotonda, William    1.106027e+09        0.0              2.0
# 2          Steans, Tyrone    1.302053e+09        0.0              0.0
# 3           Howard, Estelle  1.211051e+09        1.0              1.0
# 4               Singh, Nan   1.307060e+09        0.0              0.0
# ..                      ...           ...        ...              ...
# 268          Woodson, Jason  1.012023e+09        0.0              0.0
# 269          Blount, Dianna  1.403066e+09        0.0              0.0
# 270          Erilus, Angela  1.105026e+09        0.0              3.0
# 271  Homberger, Adrienne  J  1.207047e+09        1.0              1.0
# 272            Lundy, Susan  1.305056e+09        0.0              4.0
#
#      GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  \
# ...

# %%
df2.head(25)
# Out:
#             EmployeeName    EmployeeID  MarriedID  MaritalStatusID  GenderID  \
# 0             Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1   LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2       Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3        Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4            Singh, Nan   1.307060e+09        0.0              0.0       0.0
# 5       Smith, Leigh Ann  7.110077e+08        1.0              1.0       0.0
# 6       Bunbury, Jessica  1.504073e+09        1.0              1.0       0.0
# 7      Carter, Michelle   1.403066e+09        0.0              0.0       0.0
# 8      Dietrich, Jenna    1.408069e+09        0.0              0.0       0.0
# 9       Digitale, Alfred  1.306059e+09        1.0              1.0       1.0
# 10       Friedman, Gerry  1.204033e+09        0.0              0.0       1.0
# ...

# %%
df2.iloc[24,0]= "Jeremy,Prater"
# Out:
# C:\Users\Ron\Anaconda3\envs\dsi04\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df2.head(25)
# Out:
#             EmployeeName    EmployeeID  MarriedID  MaritalStatusID  GenderID  \
# 0             Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1   LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2       Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3        Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4            Singh, Nan   1.307060e+09        0.0              0.0       0.0
# 5       Smith, Leigh Ann  7.110077e+08        1.0              1.0       0.0
# 6       Bunbury, Jessica  1.504073e+09        1.0              1.0       0.0
# 7      Carter, Michelle   1.403066e+09        0.0              0.0       0.0
# 8      Dietrich, Jenna    1.408069e+09        0.0              0.0       0.0
# 9       Digitale, Alfred  1.306059e+09        1.0              1.0       1.0
# 10       Friedman, Gerry  1.204033e+09        0.0              0.0       1.0
# ...

# %%
df2.head(311)
# Out:
#                EmployeeName    EmployeeID  MarriedID  MaritalStatusID  \
# 0                Brown, Mia  1.103024e+09        1.0              1.0
# 1      LaRotonda, William    1.106027e+09        0.0              2.0
# 2          Steans, Tyrone    1.302053e+09        0.0              0.0
# 3           Howard, Estelle  1.211051e+09        1.0              1.0
# 4               Singh, Nan   1.307060e+09        0.0              0.0
# ..                      ...           ...        ...              ...
# 305          Daniele, Ann    1.411071e+09        1.0              1.0
# 306          Lajiri,  Jyoti  1.108028e+09        1.0              1.0
# 307  Semizoglou, Jeremiah    9.040136e+08        1.0              1.0
# 308              South, Joe  1.308061e+09        0.0              0.0
# 309         Warfield, Sarah  1.301052e+09        0.0              4.0
#
#      GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  \
# ...

# %%
def split_name(Name):
    splitval = str(Name).split(',')
    last_name, first_name = splitval[0], splitval[1]
    return [last_name, first_name]

# %%
df2['EmployeeLastName'], df2['EmployeeFirstName'] = zip(*df2.apply(lambda x: split_name(x['EmployeeName']), axis=1))
# Out:
# C:\Users\Ron\Anaconda3\envs\dsi04\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#                EmployeeName    EmployeeID  MarriedID  MaritalStatusID  \
# 0                Brown, Mia  1.103024e+09        1.0              1.0
# 1      LaRotonda, William    1.106027e+09        0.0              2.0
# 2          Steans, Tyrone    1.302053e+09        0.0              0.0
# 3           Howard, Estelle  1.211051e+09        1.0              1.0
# 4               Singh, Nan   1.307060e+09        0.0              0.0
# ..                      ...           ...        ...              ...
# 305          Daniele, Ann    1.411071e+09        1.0              1.0
# 306          Lajiri,  Jyoti  1.108028e+09        1.0              1.0
# 307  Semizoglou, Jeremiah    9.040136e+08        1.0              1.0
# 308              South, Joe  1.308061e+09        0.0              0.0
# 309         Warfield, Sarah  1.301052e+09        0.0              4.0
#
#      GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  \
# ...

# %%
df2.drop('EmployeeName', axis = 1, inplace = True)

# %%
df2
# Out:
#        EmployeeID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  DeptID  \
# 0    1.103024e+09        1.0              1.0       0.0          1.0     1.0
# 1    1.106027e+09        0.0              2.0       1.0          1.0     1.0
# 2    1.302053e+09        0.0              0.0       1.0          1.0     1.0
# 3    1.211051e+09        1.0              1.0       0.0          1.0     1.0
# 4    1.307060e+09        0.0              0.0       0.0          1.0     1.0
# ..            ...        ...              ...       ...          ...     ...
# 305  1.411071e+09        1.0              1.0       0.0          3.0     3.0
# 306  1.108028e+09        1.0              1.0       1.0          3.0     3.0
# 307  9.040136e+08        1.0              1.0       1.0          2.0     3.0
# 308  1.308061e+09        0.0              0.0       1.0          1.0     3.0
# 309  1.301052e+09        0.0              4.0       0.0          1.0     3.0
#
# ...

# %%
df2.to_csv(r'C:\Users\Ron\Documents\HRDataset_v13-2.csv')
