# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('C:/Users/Ron/Documents/core_dataset.csv')

# %%
df=df.iloc[0:301]

# %%
df.dtypes
# Out:
# Employee Name           object
# Employee Number        float64
# State                   object
# Zip                    float64
# DOB                     object
# Age                    float64
# Sex                     object
# MaritalDesc             object
# CitizenDesc             object
# Hispanic/Latino         object
# RaceDesc                object
# Date of Hire            object
# Date of Termination     object
# Reason For Term         object
# Employment Status       object
# Department              object
# Position                object
# Pay Rate               float64
# Manager Name            object
# Employee Source         object
# Performance Score       object
# dtype: object

# %%
df = df.rename(columns={'Date of Hire': 'DateofHire', 'Date of Termination':'DateofTermination', 'Pay Rate': 'PayRate', 'Employee Name': 'EmployeeName',
                          'Employee Number': 'EmployeeID', 'Reason For Term': 'ReasonForTerm', 'Manager Name':'ManagerName', 'Employee Source': 'EmployeeSource',
                            'Performance Score': 'PerformanceScore', 'Zip': 'ZipCode', 'Employment Status': 'EmploymentStatus',
                       'Hispanic/Latino': 'HispanicLatino'})

# %%
df
# Out:
#              EmployeeName    EmployeeID State  ZipCode         DOB   Age  \
# 0              Brown, Mia  1.103024e+09    MA   1450.0  11/24/1985  32.0
# 1    LaRotonda, William    1.106027e+09    MA   1460.0   4/26/1984  33.0
# 2        Steans, Tyrone    1.302053e+09    MA   2703.0    9/1/1986  31.0
# 3         Howard, Estelle  1.211051e+09    MA   2170.0   9/16/1985  32.0
# 4             Singh, Nan   1.307060e+09    MA   2330.0   5/19/1988  29.0
# ..                    ...           ...   ...      ...         ...   ...
# 296       Patronick, Luke  1.112031e+09    MA   1844.0   2/20/1979  38.0
# 297          Saada, Adell  1.012023e+09    MA   2132.0   7/24/1986  31.0
# 298         Szabo, Andrew  1.201031e+09    MA   2140.0    5/6/1983  34.0
# 299          True, Edward  1.102024e+09    MA   2451.0   6/14/1983  34.0
# 300      Sweetwater, Alex  1.001645e+09    MA   2184.0  11/22/1966  51.0
#
#         Sex MaritalDesc  CitizenDesc HispanicLatino  ...  DateofHire  \
# ...

# %%
df['DOB']=pd.to_datetime(df['DOB'])

# %%
df['DateofHire'] = pd.to_datetime(df['DateofHire'])

# %%
df['DateofTermination'] = pd.to_datetime(df['DateofTermination'])

# %%
df.dtypes
# Out:
# EmployeeName                 object
# EmployeeID                  float64
# State                        object
# ZipCode                     float64
# DOB                  datetime64[ns]
# Age                         float64
# Sex                          object
# MaritalDesc                  object
# CitizenDesc                  object
# HispanicLatino               object
# RaceDesc                     object
# DateofHire           datetime64[ns]
# DateofTermination    datetime64[ns]
# ReasonForTerm                object
# EmploymentStatus             object
# Department                   object
# Position                     object
# PayRate                     float64
# ManagerName                  object
# EmployeeSource               object
# PerformanceScore             object
# dtype: object

# %%
df['Salary'] = df.PayRate*40*52

# %%
df
# Out:
#              EmployeeName    EmployeeID State  ZipCode        DOB   Age  \
# 0              Brown, Mia  1.103024e+09    MA   1450.0 1985-11-24  32.0
# 1    LaRotonda, William    1.106027e+09    MA   1460.0 1984-04-26  33.0
# 2        Steans, Tyrone    1.302053e+09    MA   2703.0 1986-09-01  31.0
# 3         Howard, Estelle  1.211051e+09    MA   2170.0 1985-09-16  32.0
# 4             Singh, Nan   1.307060e+09    MA   2330.0 1988-05-19  29.0
# ..                    ...           ...   ...      ...        ...   ...
# 296       Patronick, Luke  1.112031e+09    MA   1844.0 1979-02-20  38.0
# 297          Saada, Adell  1.012023e+09    MA   2132.0 1986-07-24  31.0
# 298         Szabo, Andrew  1.201031e+09    MA   2140.0 1983-05-06  34.0
# 299          True, Edward  1.102024e+09    MA   2451.0 1983-06-14  34.0
# 300      Sweetwater, Alex  1.001645e+09    MA   2184.0 1966-11-22  51.0
#
#         Sex MaritalDesc  CitizenDesc HispanicLatino  ... DateofTermination  \
# ...

# %%
df['MaritalDesc']=df['MaritalDesc'].str.capitalize()

# %%
df.head(53)
# Out:
#                 EmployeeName    EmployeeID State  ZipCode        DOB   Age  \
# 0                 Brown, Mia  1.103024e+09    MA   1450.0 1985-11-24  32.0
# 1       LaRotonda, William    1.106027e+09    MA   1460.0 1984-04-26  33.0
# 2           Steans, Tyrone    1.302053e+09    MA   2703.0 1986-09-01  31.0
# 3            Howard, Estelle  1.211051e+09    MA   2170.0 1985-09-16  32.0
# 4                Singh, Nan   1.307060e+09    MA   2330.0 1988-05-19  29.0
# 5           Smith, Leigh Ann  7.110077e+08    MA   1844.0 1987-06-14  30.0
# 6        LeBlanc, Brandon  R  1.102024e+09    MA   1460.0 1984-06-10  33.0
# 7                Quinn, Sean  1.206043e+09    MA   2045.0 1984-11-06  33.0
# 8          Boutwell, Bonalyn  1.307060e+09    MA   2468.0 1987-04-04  30.0
# 9          Foster-Baker, Amy  1.201031e+09    MA   2050.0 1979-04-16  38.0
# 10               King, Janet  1.001495e+09    MA   1902.0 1954-09-21  63.0
# ...

# %%
df.dtypes
# Out:
# EmployeeName                 object
# EmployeeID                  float64
# State                        object
# ZipCode                     float64
# DOB                  datetime64[ns]
# Age                         float64
# Sex                          object
# MaritalDesc                  object
# CitizenDesc                  object
# HispanicLatino               object
# RaceDesc                     object
# DateofHire           datetime64[ns]
# DateofTermination    datetime64[ns]
# ReasonForTerm                object
# EmploymentStatus             object
# Department                   object
# Position                     object
# PayRate                     float64
# ManagerName                  object
# EmployeeSource               object
# PerformanceScore             object
# Salary                      float64
# dtype: object

# %%
df.head(273)
# Out:
#              EmployeeName    EmployeeID State  ZipCode        DOB   Age  \
# 0              Brown, Mia  1.103024e+09    MA   1450.0 1985-11-24  32.0
# 1    LaRotonda, William    1.106027e+09    MA   1460.0 1984-04-26  33.0
# 2        Steans, Tyrone    1.302053e+09    MA   2703.0 1986-09-01  31.0
# 3         Howard, Estelle  1.211051e+09    MA   2170.0 1985-09-16  32.0
# 4             Singh, Nan   1.307060e+09    MA   2330.0 1988-05-19  29.0
# ..                    ...           ...   ...      ...        ...   ...
# 268       Gill, Whitney    1.302053e+09    OH  43050.0 1971-07-10  46.0
# 269        Givens, Myriam  1.203032e+09    IN  46204.0 1989-09-22  28.0
# 270     Gonzales, Ricardo  1.411071e+09    ID  83706.0 1954-10-12  63.0
# 271       Guilianno, Mike  1.001167e+09    TN  37129.0 1969-02-09  48.0
# 272         Jeremy Prater  1.001085e+09    NV  89139.0 1974-05-09  43.0
#
#         Sex MaritalDesc CitizenDesc HispanicLatino  ... DateofTermination  \
# ...

# %%
df.iloc[272,0] = "Jeremy, Prater"

# %%
df.head(273)
# Out:
#              EmployeeName    EmployeeID State  ZipCode        DOB   Age  \
# 0              Brown, Mia  1.103024e+09    MA   1450.0 1985-11-24  32.0
# 1    LaRotonda, William    1.106027e+09    MA   1460.0 1984-04-26  33.0
# 2        Steans, Tyrone    1.302053e+09    MA   2703.0 1986-09-01  31.0
# 3         Howard, Estelle  1.211051e+09    MA   2170.0 1985-09-16  32.0
# 4             Singh, Nan   1.307060e+09    MA   2330.0 1988-05-19  29.0
# ..                    ...           ...   ...      ...        ...   ...
# 268       Gill, Whitney    1.302053e+09    OH  43050.0 1971-07-10  46.0
# 269        Givens, Myriam  1.203032e+09    IN  46204.0 1989-09-22  28.0
# 270     Gonzales, Ricardo  1.411071e+09    ID  83706.0 1954-10-12  63.0
# 271       Guilianno, Mike  1.001167e+09    TN  37129.0 1969-02-09  48.0
# 272        Jeremy, Prater  1.001085e+09    NV  89139.0 1974-05-09  43.0
#
#         Sex MaritalDesc CitizenDesc HispanicLatino  ... DateofTermination  \
# ...

# %%
def split_name(Name):
    splitval = str(Name).split(',')
    last_name, first_name = splitval[0], splitval[1]
    return [last_name, first_name]

# %%
df['EmployeeLastName'], df['EmployeeFirstName'] = zip(*df.apply(lambda x: split_name(x['EmployeeName']), axis=1))

# %%
df
# Out:
#              EmployeeName    EmployeeID State  ZipCode        DOB   Age  \
# 0              Brown, Mia  1.103024e+09    MA   1450.0 1985-11-24  32.0
# 1    LaRotonda, William    1.106027e+09    MA   1460.0 1984-04-26  33.0
# 2        Steans, Tyrone    1.302053e+09    MA   2703.0 1986-09-01  31.0
# 3         Howard, Estelle  1.211051e+09    MA   2170.0 1985-09-16  32.0
# 4             Singh, Nan   1.307060e+09    MA   2330.0 1988-05-19  29.0
# ..                    ...           ...   ...      ...        ...   ...
# 296       Patronick, Luke  1.112031e+09    MA   1844.0 1979-02-20  38.0
# 297          Saada, Adell  1.012023e+09    MA   2132.0 1986-07-24  31.0
# 298         Szabo, Andrew  1.201031e+09    MA   2140.0 1983-05-06  34.0
# 299          True, Edward  1.102024e+09    MA   2451.0 1983-06-14  34.0
# 300      Sweetwater, Alex  1.001645e+09    MA   2184.0 1966-11-22  51.0
#
#         Sex MaritalDesc  CitizenDesc HispanicLatino  ...  \
# ...

# %%
df.drop('EmployeeName', axis = 1, inplace = True)

# %%
df
# Out:
#        EmployeeID State  ZipCode        DOB   Age     Sex MaritalDesc  \
# 0    1.103024e+09    MA   1450.0 1985-11-24  32.0  Female     Married
# 1    1.106027e+09    MA   1460.0 1984-04-26  33.0    Male    Divorced
# 2    1.302053e+09    MA   2703.0 1986-09-01  31.0    Male      Single
# 3    1.211051e+09    MA   2170.0 1985-09-16  32.0  Female     Married
# 4    1.307060e+09    MA   2330.0 1988-05-19  29.0  Female      Single
# ..            ...   ...      ...        ...   ...     ...         ...
# 296  1.112031e+09    MA   1844.0 1979-02-20  38.0    Male      Single
# 297  1.012023e+09    MA   2132.0 1986-07-24  31.0  Female     Married
# 298  1.201031e+09    MA   2140.0 1983-05-06  34.0    Male      Single
# 299  1.102024e+09    MA   2451.0 1983-06-14  34.0    Male      Single
# 300  1.001645e+09    MA   2184.0 1966-11-22  51.0    Male      Single
#
#      CitizenDesc HispanicLatino                   RaceDesc  ...  \
# ...

# %%
df.iloc[16,13]
# Out:
# 'Leave of Absence'

# %%
df.to_csv(r'C:\Users\Ron\Documents\core_dataset2.csv')
